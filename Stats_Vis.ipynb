# %%
import os
import sys
import pathlib
import dendropy
import argparse
import pandas as pd
from dendropy.calculate import treecompare as tc
from dendropy.calculate import treemeasure as tm

# %%
def pairwise_tree_stats(tree_dir,  base_tree):
        tree_files = [f for f in os.listdir(tree_dir) if f.endswith(".tre")]
        df = pd.DataFrame()
        btree = base_tree
        tns = dendropy.TaxonNamespace()
        t1 = dendropy.Tree.get(
                file = open(base_tree),
                schema = "newick",
                taxon_namespace = tns
                )


        for file  in tree_files:
                t2_name = str(file)[:-len("_biCons.tre")]
                t2 = dendropy.Tree.get(
                        file = open(base_tree),
                        schema = "newick",
                        taxon_namespace = tns
                        )
                tns,t1,t2 = standardize_namespace(tns, t1, t2)
                t1.encode_bipartitions()
                t2.encode_bipartitions()
                fal_pos_neg = tc.false_positives_and_negatives(t1, t2)

                row_data = {
                        'BaseTree':btree,
                        'genTree':t2_name,
                        'falePosBip':fal_pos_neg[0],
                        'falseNegBip':fal_pos_neg[1],
                        'uRF':tc.symmetric_difference(t1,t2),
                        'wRF':tc.weighted_robinson_foulds_distance(t1,t2),
                        'sackinBase':tm.sackin_index(t1),
                        'sackinGen':tm.sackin_index(t2)
                }
                df = df.append(row_data, ignore_index = True)
        df =df[['BaseTree', 'genTree', 'falePosBip', 'falseNegBip', 'uRF', 'wRF', 'sackinBase', 'sackinGen']]

        return df
    
def standardize_namespace(tns, t1, t2):
    """requires two trees with a common taxon namespace"""
    tree_1_taxa = set()
    tree_2_taxa = set()

    for tip in t1.leaf_node_iter():
        tree_1_taxa.add(tip.taxon)

    for tip in t2.leaf_node_iter():
        tree_2_taxa.add(tip.taxon)

    shared_taxa = tree_1_taxa.intersection(tree_2_taxa)

    assert(len(shared_taxa) >= 1)
    #print("These two trees have {s} shared taxa".format(s=len(shared_taxa)))

    t1.retain_taxa(shared_taxa)
    t2.retain_taxa(shared_taxa)
    return(tns, t1, t2)

# %%
pairwise_tree_stats("bestTrees/", 'example.tre')
# Out:
# <ipython-input-4-98c159cd9c69>:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row_data, ignore_index = True)
# <ipython-input-4-98c159cd9c69>:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row_data, ignore_index = True)
# <ipython-input-4-98c159cd9c69>:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row_data, ignore_index = True)
# <ipython-input-4-98c159cd9c69>:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row_data, ignore_index = True)
# <ipython-input-4-98c159cd9c69>:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row_data, ignore_index = True)
# <ipython-input-4-98c159cd9c69>:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row_data, ignore_index = True)
# <ipython-input-4-98c159cd9c69>:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row_data, ignore_index = True)
# <ipython-input-4-98c159cd9c69>:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row_data, ignore_index = True)
# <ipython-input-4-98c159cd9c69>:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row_data, ignore_index = True)
# <ipython-input-4-98c159cd9c69>:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row_data, ignore_index = True)
# <ipython-input-4-98c159cd9c69>:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row_data, ignore_index = True)
# <ipython-input-4-98c159cd9c69>:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row_data, ignore_index = True)
# <ipython-input-4-98c159cd9c69>:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row_data, ignore_index = True)
# <ipython-input-4-98c159cd9c69>:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row_data, ignore_index = True)
# <ipython-input-4-98c159cd9c69>:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row_data, ignore_index = True)
# <ipython-input-4-98c159cd9c69>:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row_data, ignore_index = True)
# <ipython-input-4-98c159cd9c69>:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row_data, ignore_index = True)
# <ipython-input-4-98c159cd9c69>:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row_data, ignore_index = True)
# <ipython-input-4-98c159cd9c69>:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row_data, ignore_index = True)
# <ipython-input-4-98c159cd9c69>:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row_data, ignore_index = True)
# <ipython-input-4-98c159cd9c69>:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row_data, ignore_index = True)
# <ipython-input-4-98c159cd9c69>:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row_data, ignore_index = True)
# <ipython-input-4-98c159cd9c69>:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row_data, ignore_index = True)
#        BaseTree genTree  falePosBip  falseNegBip  uRF  wRF  sackinBase  \
# 0   example.tre     s23           0            0    0  0.0         5.0
# 1   example.tre     s22           0            0    0  0.0         5.0
# 2   example.tre      s1           0            0    0  0.0         5.0
# 3   example.tre     s11           0            0    0  0.0         5.0
# 4   example.tre     s20           0            0    0  0.0         5.0
# 5   example.tre     s18           0            0    0  0.0         5.0
# 6   example.tre      s4           0            0    0  0.0         5.0
# 7   example.tre     s21           0            0    0  0.0         5.0
# 8   example.tre     s19           0            0    0  0.0         5.0
# 9   example.tre      s9           0            0    0  0.0         5.0
# 10  example.tre     s15           0            0    0  0.0         5.0
# 11  example.tre     s10           0            0    0  0.0         5.0
# 12  example.tre     s16           0            0    0  0.0         5.0
# 13  example.tre     s17           0            0    0  0.0         5.0
# 14  example.tre      s7           0            0    0  0.0         5.0
# 15  example.tre     s24           0            0    0  0.0         5.0
# 16  example.tre     s12           0            0    0  0.0         5.0
# 17  example.tre     s14           0            0    0  0.0         5.0
# 18  example.tre      s3           0            0    0  0.0         5.0
# 19  example.tre     s13           0            0    0  0.0         5.0
# 20  example.tre      s2           0            0    0  0.0         5.0
# 21  example.tre      s6           0            0    0  0.0         5.0
# 22  example.tre      s8           0            0    0  0.0         5.0
#
#     sackinGen
# 0         5.0
# 1         5.0
# 2         5.0
# 3         5.0
# 4         5.0
# 5         5.0
# 6         5.0
# 7         5.0
# 8         5.0
# 9         5.0
# 10        5.0
# 11        5.0
# 12        5.0
# 13        5.0
# 14        5.0
# 15        5.0
# 16        5.0
# 17        5.0
# 18        5.0
# 19        5.0
# 20        5.0
# 21        5.0
# 22        5.0
